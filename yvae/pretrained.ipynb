# %%
import tensorflow as tf

# %%
eff=tf.keras.applications.efficientnet.EfficientNetB0(include_top=False,input_shape=(64,64,3))

# %%
eff.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_19 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# rescaling_10 (Rescaling)        (None, 64, 64, 3)    0           input_19[0][0]
# __________________________________________________________________________________________________
# normalization_6 (Normalization) (None, 64, 64, 3)    7           rescaling_10[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 65, 65, 3)    0           normalization_6[0][0]
# __________________________________________________________________________________________________
# ...

# %%
eff.output_shape
# Out:
# (None, 2, 2, 1280)

# %%
mnv3s=tf.keras.applications.MobileNetV3Small(include_top=False,input_shape=(64,64,3))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
mnv3s.summary()
# Out:
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_20 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# rescaling_11 (Rescaling)        (None, 64, 64, 3)    0           input_20[0][0]
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, 32, 32, 16)   432         rescaling_11[0][0]
# __________________________________________________________________________________________________
# Conv/BatchNorm (BatchNormalizat (None, 32, 32, 16)   64          Conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
mnv3s.output_shape
# Out:
# (None, 2, 2, 1024)

# %%
inc=tf.keras.applications.inception_v3.InceptionV3(input_shape=(128,128,3),include_top=False)

# %%
inc.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_21 (InputLayer)           [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 63, 63, 32)   864         input_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 63, 63, 32)   96          conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 63, 63, 32)   0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# ...

# %%
res=tf.keras.applications.resnet_v2.ResNet101V2(include_top=False,input_shape=(64,64,3))

# %%
res.summary()
# Out:
# Model: "resnet101v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_22 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 70, 3)    0           input_22[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 34, 34, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 16, 16, 64)   0           pool1_pad[0][0]
# ...

# %%
dir(tf.keras.applications)
# Out:
# ['DenseNet121',
#  'DenseNet169',
#  'DenseNet201',
#  'EfficientNetB0',
#  'EfficientNetB1',
#  'EfficientNetB2',
#  'EfficientNetB3',
#  'EfficientNetB4',
#  'EfficientNetB5',
#  'EfficientNetB6',
#  'EfficientNetB7',
#  'InceptionResNetV2',
#  'InceptionV3',
#  'MobileNet',
#  'MobileNetV2',
#  'MobileNetV3Large',
#  'MobileNetV3Small',
#  'NASNetLarge',
#  'NASNetMobile',
#  'ResNet101',
#  'ResNet101V2',
#  'ResNet152',
#  'ResNet152V2',
#  'ResNet50',
#  'ResNet50V2',
#  'VGG16',
#  'VGG19',
#  'Xception',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_sys',
#  'densenet',
#  'efficientnet',
#  'imagenet_utils',
#  'inception_resnet_v2',
#  'inception_v3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3',
#  'nasnet',
#  'resnet',
#  'resnet50',
#  'resnet_v2',
#  'vgg16',
#  'vgg19',
#  'xception']

# %%
tf.keras.applications.efficientnet.EfficientNetB7(include_top=False,input_shape=(64,64,3)).summary()
# Out:
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_23 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# rescaling_12 (Rescaling)        (None, 64, 64, 3)    0           input_23[0][0]
# __________________________________________________________________________________________________
# normalization_7 (Normalization) (None, 64, 64, 3)    7           rescaling_12[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 65, 65, 3)    0           normalization_7[0][0]
# __________________________________________________________________________________________________
# ...

# %%
tf.keras.applications.efficientnet.EfficientNetB0(include_top=True).summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_24 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# rescaling_13 (Rescaling)        (None, 224, 224, 3)  0           input_24[0][0]
# __________________________________________________________________________________________________
# normalization_8 (Normalization) (None, 224, 224, 3)  7           rescaling_13[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 225, 225, 3)  0           normalization_8[0][0]
# __________________________________________________________________________________________________
# ...

# %%
tf.keras.applications.MobileNetV3Small().summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_25 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# rescaling_14 (Rescaling)        (None, None, None, 3 0           input_25[0][0]
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, None, None, 1 432         rescaling_14[0][0]
# __________________________________________________________________________________________________
# Conv/BatchNorm (BatchNormalizat (None, None, None, 1 64          Conv[0][0]
# ...

# %%
eff

# %%
eff.name
# Out:
# 'efficientnetb0'

# %%
from yvae_model import *

# %%
ext=get_external_classifier((64,64,3),VGG,3)
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_26 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# ...

# %%
ext.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 ext.summary()
#
# File ~/.conda/envs/fine-tune/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:2376, in Model.summary(self, line_length, positions, print_fn)
#    2358 """Prints a string summary of the network.
#    2359
#    2360 Arguments:
#    (...)
#    2373     ValueError: if `summary()` is called before the model is built.
#    2374 """
#    2375 if not self.built:
# -> 2376   raise ValueError('This model has not yet been built. '
#    2377                    'Build the model first by calling `build()` or calling '
#    2378                    '`fit()` with some data, or specify '
#    2379                    'an `input_shape` argument in the first layer(s) for '
#    2380                    'automatic build.')
#    2381 layer_utils.print_summary(self,
# ...

# %%
ext.get_layer(EXTERNAL_MODEL)

# %%
opt=tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
opt.learning_rate
# Out:
# <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>

# %%
opt.learning_rate.numpy()
# Out:
# 0.001

# %%
tf.keras.applications.NASNetMobile((64,64,3), include_top=False,weights=)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 tf.keras.applications.NASNetMobile((64,64,3), include_top=False)
#
# File ~/.conda/envs/fine-tune/lib/python3.9/site-packages/tensorflow/python/keras/applications/nasnet.py:384, in NASNetMobile(input_shape, include_top, weights, input_tensor, pooling, classes)
#     322 @keras_export('keras.applications.nasnet.NASNetMobile',
#     323               'keras.applications.NASNetMobile')
#     324 def NASNetMobile(input_shape=None,
#    (...)
#     328                  pooling=None,
#     329                  classes=1000):
#     330   """Instantiates a Mobile NASNet model in ImageNet mode.
#     331
#     332   Reference:
#    (...)
#     382           backend that does not support separable convolutions.
#     383   """
# --> 384   return NASNet(
#     385       input_shape,
# ...

# %%
dir(tf.keras.layers)
# Out:
# ['AbstractRNNCell',
#  'Activation',
#  'ActivityRegularization',
#  'Add',
#  'AdditiveAttention',
#  'AlphaDropout',
#  'Attention',
#  'Average',
#  'AveragePooling1D',
#  'AveragePooling2D',
#  'AveragePooling3D',
#  'AvgPool1D',
#  'AvgPool2D',
#  'AvgPool3D',
#  'BatchNormalization',
#  'Bidirectional',
#  'Concatenate',
#  'Conv1D',
#  'Conv1DTranspose',
#  'Conv2D',
#  'Conv2DTranspose',
#  'Conv3D',
#  'Conv3DTranspose',
#  'ConvLSTM2D',
#  'Convolution1D',
#  'Convolution1DTranspose',
#  'Convolution2D',
#  'Convolution2DTranspose',
#  'Convolution3D',
#  'Convolution3DTranspose',
#  'Cropping1D',
#  'Cropping2D',
#  'Cropping3D',
#  'Dense',
#  'DenseFeatures',
#  'DepthwiseConv2D',
#  'Dot',
#  'Dropout',
#  'ELU',
#  'Embedding',
#  'Flatten',
#  'GRU',
#  'GRUCell',
#  'GaussianDropout',
#  'GaussianNoise',
#  'GlobalAveragePooling1D',
#  'GlobalAveragePooling2D',
#  'GlobalAveragePooling3D',
#  'GlobalAvgPool1D',
#  'GlobalAvgPool2D',
#  'GlobalAvgPool3D',
# ...

# %%
dir(tf.keras.layers.experimental.preprocessing)
# Out:
# ['CategoryCrossing',
#  'CategoryEncoding',
#  'CenterCrop',
#  'Discretization',
#  'Hashing',
#  'IntegerLookup',
#  'Normalization',
#  'PreprocessingLayer',
#  'RandomContrast',
#  'RandomCrop',
#  'RandomFlip',
#  'RandomHeight',
#  'RandomRotation',
#  'RandomTranslation',
#  'RandomWidth',
#  'RandomZoom',
#  'Rescaling',
#  'Resizing',
#  'StringLookup',
#  'TextVectorization',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_sys']

# %%
tf.keras.applications.resnet_v2.ResNet152V2
# Out:
# <function tensorflow.python.keras.applications.resnet_v2.ResNet152V2(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>
