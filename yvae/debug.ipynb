# %%
from yvae_model import *
# Out:
# 2023-05-23 23:34:48.318368: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
input_shape=(32,32,3)
latent_dim=8
start_layer='encoder_bn_2'

# %%
inputs = Input(shape=input_shape, name='encoder_input')
encoder=get_encoder(inputs, latent_dim)
# Out:
# 2023-05-23 23:36:07.209412: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-05-23 23:36:07.210184: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/jlb638/cuda/lib64:/home/jlb638/packages/gdb/lib:/home/jlb638/packages/gcc/lib64:/home/jlb638/packages/gcc/lib:/home/jlb638/packages/gmp/5_0_2/include:/home/jlb638/packages/gmp/5_0_2/lib:/home/jlb638/texinfo/6_6/lib:/home/jlb638/gc563/python/3.9.6/lib:/home/jlb638/cuda/lib64:/home/jlb638/packages/gdb/lib:/home/jlb638/packages/gcc/lib64:/home/jlb638/packages/gcc/lib:/home/jlb638/packages/gmp/5_0_2/include:/home/jlb638/packages/gmp/5_0_2/lib:/home/jlb638/texinfo/6_6/lib:/home/jlb638/gc563/python/3.9.6/lib:
# 2023-05-23 23:36:07.210236: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-23 23:36:07.210313: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (amarel2.amarel.rutgers.edu): /proc/driver/nvidia/version does not exist
# 2023-05-23 23:36:07.210900: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-23 23:36:07.221394: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# WARNING:tensorflow:AutoGraph could not transform <function sampling at 0x7fc4b40ba5e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function sampling at 0x7fc4b40ba5e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
pretrained_input_shape=encoder.get_layer(start_layer).input_shape
print(pretrained_input_shape)
partial=get_shared_partial(encoder, start_layer, latent_dim)
# Out:
# (None, 8, 8, 128)
# WARNING:tensorflow:Functional model inputs must come from `tf.keras.Input` (thus holding past layer metadata), they cannot be the output of a previous non-Input layer. Here, a tensor specified as input to "shared_encoder" was not an Input tensor, it was generated by layer encoder_conv_5.
# Note that input tensors are instantiated via `tensor = tf.keras.Input(shape)`.
# The tensor that caused the issue was: encoder_conv_5/Relu:0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 pretrained_input_shape=encoder.get_layer(start_layer).input_shape
#       2 print(pretrained_input_shape)
# ----> 3 partial=get_shared_partial(encoder, start_layer, latent_dim)
#
# File /cache/home/jlb638/Desktop/vae_plus/yvae/yvae_model.py:74, in get_shared_partial(pretrained_encoder, start_name, latent_dim)
#      72 z_mean=pretrained_encoder.get_layer('z_mean')(x)
#      73 z_log_var =pretrained_encoder.get_layer('z_log_var')(x)
# ---> 74 return Model(inputs, [z_mean, z_log_var, SamplingLayer(name='z')([z_mean, z_log_var,latent_dim])], name=SHARED_ENCODER_NAME)
#
# File ~/.conda/envs/fine-tune/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py:517, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     515 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516 try:
# --> 517   result = method(self, *args, **kwargs)
#     518 finally:
#     519   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/.conda/envs/fine-tune/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:120, in Functional.__init__(self, inputs, outputs, name, trainable, **kwargs)
#     118 generic_utils.validate_kwargs(kwargs, {})
#     119 super(Functional, self).__init__(name=name, trainable=trainable)
# --> 120 self._init_graph_network(inputs, outputs)
#
# File ~/.conda/envs/fine-tune/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py:517, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     515 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516 try:
# --> 517   result = method(self, *args, **kwargs)
#     518 finally:
#     519   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/.conda/envs/fine-tune/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:203, in Functional._init_graph_network(self, inputs, outputs)
#     200   self._input_coordinates.append((layer, node_index, tensor_index))
#     202 # Keep track of the network's nodes and layers.
# --> 203 nodes, nodes_by_depth, layers, _ = _map_graph_network(
#     204     self.inputs, self.outputs)
#     205 self._network_nodes = nodes
#     206 self._nodes_by_depth = nodes_by_depth
#
# File ~/.conda/envs/fine-tune/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:985, in _map_graph_network(inputs, outputs)
#     983 for x in nest.flatten(node.keras_inputs):
#     984   if id(x) not in computable_tensors:
# --> 985     raise ValueError('Graph disconnected: '
#     986                      'cannot obtain value for tensor ' + str(x) +
#     987                      ' at layer "' + layer.name + '". '
#     988                      'The following previous layers '
#     989                      'were accessed without issue: ' +
#     990                      str(layers_with_complete_input))
#     991 for x in nest.flatten(node.outputs):
#     992   computable_tensors.add(id(x))
#
# ValueError: Graph disconnected: cannot obtain value for tensor KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name='encoder_input'), name='encoder_input', description="created by layer 'encoder_input'") at layer "encoder_conv_0". The following previous layers were accessed without issue: []
